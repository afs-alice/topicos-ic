# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
my_dataset = pd.read_csv('books.csv', error_bad_lines = False)

my_dataset = pd.DataFrame(my_dataset)

# average_rating definido como target
X = my_dataset.iloc[:, 3].values.reshape(-1, 1)
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'

# %%
# num_pages
y = my_dataset.iloc[:, 7].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(X, y)

linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)
Y_pred = linear_regressor.predict(X)

#Mostrando dos resultados
# coeficientes
print("Coeficiente: {}".format(linear_regressor.coef_))
    
# erro quadrado médio
print("Erro Quadrado Médio: ", np.mean((linear_regressor.predict
                                        (x_test) - y_test) ** 2))

# variância
print("Variância: ", linear_regressor.score(x_test, y_test))
# Out:
# Coeficiente: [[100.90383999]]
# Erro Quadrado Médio:  62683.35457872888
# Variância:  0.02257965318743005

# %%
plt.scatter(X, y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
plt.style.use('fivethirtyeight') 
  
# plotagem dos erros residuais em dados de treinamento
plt.scatter(linear_regressor.predict(x_train), linear_regressor.predict
            (x_train) - y_train, color = "green", s = 15, label = 'Treino') 
  
# plotagem dos erros residuais em dados de teste
plt.scatter(linear_regressor.predict(x_test), linear_regressor.predict
            (x_test) - y_test, color = "blue", s = 15, label = 'Teste')

plt.legend(loc = 'best') 

plt.title("Erros Residuais") 

plt.show()

# %%
print('Erro Médio Absoluto:', metrics.mean_absolute_error(y, Y_pred))

print('Erro Quadrático Médio:', metrics.mean_squared_error(y, Y_pred))

print('Raiz Quadrada do Erro Médio:', np.sqrt(metrics.mean_squared_error(y, Y_pred)))

print('R2 Treino:', metrics.r2_score(x_train, y_train))

print('R2 Teste:', metrics.r2_score(x_test, y_test))

print('R2:', np.sqrt(metrics.r2_score(y, Y_pred)))

print('Intercept:', linear_regressor.intercept_)
# Out:
# Erro Médio Absoluto: 157.61085877108835
# Erro Quadrático Médio: 56842.11372637629
# Raiz Quadrada do Erro Médio: 238.41584202056768
# R2 Treino: -1368638.9004178133
# R2 Teste: -1385618.2309432821
# R2: 0.1499361608348038
# Intercept: [-63.48863929]

# %%
#rating_counts
y = my_dataset.iloc[:, 8].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(X, y)

linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)
Y_pred = linear_regressor.predict(X)

#Mostrando dos resultados
# coeficientes
print("Coeficiente: ", linear_regressor.coef_)

# erro quadrado médio
print("Erro Quadrado Médio: ", np.mean((linear_regressor.predict
                                        (x_test) - y_test) ** 2))

# variância
print("Variância: ", linear_regressor.score(x_test, y_test))
# Out:
# Coeficiente:  [[12207.15246138]]
# Erro Quadrado Médio:  9590232105.343449
# Variância:  0.0018129123368104683

# %%
plt.scatter(X, y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
plt.style.use('fivethirtyeight') 
  
# plotagem dos erros residuais em dados de treinamento
plt.scatter(linear_regressor.predict(x_train), linear_regressor.predict
            (x_train) - y_train, color = "green", s = 15, label = 'Treino') 
  
# plotagem dos erros residuais em dados de teste
plt.scatter(linear_regressor.predict(x_test), linear_regressor.predict
            (x_test) - y_test, color = "blue", s = 15, label = 'Teste')

plt.legend(loc = 'best') 

plt.title("Erros Residuais") 

plt.show()

# %%
print('Erro Médio Absoluto:', metrics.mean_absolute_error(y, Y_pred))

print('Erro Quadrático Médio:', metrics.mean_squared_error(y, Y_pred))

print('Raiz Quadrada do Erro Médio:', np.sqrt(metrics.mean_squared_error(y, Y_pred)))

print('R2 Treino:', metrics.r2_score(x_train, y_train))

print('R2 Teste:', metrics.r2_score(x_test, y_test))

print('R2:', np.sqrt(metrics.r2_score(y, Y_pred)))

print('Intercept:', linear_regressor.intercept_)
# Out:
# Erro Médio Absoluto: 28051.373531139958
# Erro Quadrático Médio: 12636627924.96588
# Raiz Quadrada do Erro Médio: 112412.75694940446
# R2 Treino: -116815610001.73912
# R2 Teste: -75140161025.83342
# R2: 0.038020863909183356
# Intercept: [-29639.26852949]

# %%
#text_review_count
y = my_dataset.iloc[:, 9].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(X, y)

linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)
Y_pred = linear_regressor.predict(X)

#Mostrando dos resultados
# coeficientes
print("Coeficiente: {}".format(linear_regressor.coef_))
    
# erro quadrado médio
print("Erro Quadrado Médio: ", np.mean((linear_regressor.predict
                                        (x_test) - y_test) ** 2))

# variância
print("Variância: ", linear_regressor.score(x_test, y_test))
# Out:
# Coeficiente: [[234.81064612]]
# Erro Quadrado Médio:  6576897.581641745
# Variância:  0.0014279076969725413

# %%
plt.scatter(X, y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
print('Erro Médio Absoluto:', metrics.mean_absolute_error(y, Y_pred))

print('Erro Quadrático Médio:', metrics.mean_squared_error(y, Y_pred))

print('Raiz Quadrada do Erro Médio:', np.sqrt(metrics.mean_squared_error
                                              (y, Y_pred)))

print('R2 Treino:', metrics.r2_score(x_train, y_train))

print('R2 Teste:', metrics.r2_score(x_test, y_test))

print('R2:', np.sqrt(metrics.r2_score(y, Y_pred)))

print('Intercept:', linear_regressor.intercept_)
# Out:
# Erro Médio Absoluto: 775.6154579663373
# Erro Quadrático Médio: 6630880.022310236
# Raiz Quadrada do Erro Médio: 2575.0495184190604
# R2 Treino: -56166418.642112136
# R2 Teste: -57134023.99628674
# R2: 0.03359363708626094
# Intercept: [-385.06682259]

# %%
plt.style.use('fivethirtyeight') 
  
# plotagem dos erros residuais em dados de treinamento
plt.scatter(linear_regressor.predict(x_train), linear_regressor.predict
            (x_train) - y_train, color = "green", s = 15, label = 'Treino') 
  
# plotagem dos erros residuais em dados de teste
plt.scatter(linear_regressor.predict(x_test), linear_regressor.predict
            (x_test) - y_test, color = "blue", s = 15, label = 'Teste')

plt.legend(loc = 'best') 

plt.title("Erros Residuais") 

plt.show()

# %% [markdown]
# **Referências**
#
#
# [Regressão Linear e Multilinear](https://brunogolfette.com.br/artigos/linear_polinomial_models/)
#
# [Linear Regression](https://www.statsmodels.org/stable/regression.html)
#
# [Aplicando Regressão Linear com Scikit-Learn](https://matheusfacure.github.io/2017/07/19/MQO-sklearn/)
#
# [Interpreting Data using Statistical Models with Python](https://www.pluralsight.com/guides/interpreting-data-using-statistical-models-python)
#
# [Linear Regression in Python](https://realpython.com/linear-regression-in-python/)
